# %% [markdown]
# ### Designing a pipeline to rank reviews on drugs
#
# Before trying new drugs, most patients usually look for other patients' opinions who have had the same conditions and used the same medications. However, most of the reviews that other patients write may not be helpful to be shown to new patients. Therefore, as patients submit the reviews, it would be very helpful to rank them based on their usefulness to new patients. To this end, a pipeline has been designed and trained in this study. The pipeline consists of two major components: **a)** preprocessing and **b)** a deep learning model. The preprocessing component is shown in the schematic below.
# ### Preprocessing pipeline:
# ![Presentation1.png](attachment:0150b022-527a-4ec3-bbbf-7217a194201d.png)
# It is noteworthy that we transformed output (useful counts) using a Box-Cox transformation, for both modeling and deploying. Therefore, the output **ranked reviews** will take palce in this tranformed space. We found that this transformation helps model better handle the noises in output.
#
# ### Deep Learning model:
# The deep learning model consists of embedding and bidirectional LSTM layers, as shown below.
#
# ![lstm_model.png](attachment:108d1670-8ddc-4bb8-b065-5cccb57b1433.png)
#
# ### Datasets for training and testing the model
#
# In this study, we use a drug reviews dataset that is avialalbe at :  https://archive.ics.uci.edu/ml/datasets/Drug+Review+Dataset+%28Drugs.com%29
# This dataset includes *training* and *test* sets as two different files.

# %% [markdown]
# ### Installing module
# You can simply clone the entire repository by executing:
# ```bash
# git clone git@github.com:saeeron/rankDrugRev.git
#
# ```
# \*`rankDrugRev.py` is the only module, while other files are pretrained models and depedencies.

# %% [markdown]
# ### Dependencies
# The packages in the envirment where this model was developed can be found in `dependencies.txt`. Importantly, the deep learning tool used in this study is `tensorflow-gpu==2.4.1`  as engaged with *CUDA Toolkit 11.0* and *cuDNN 8.0* (device: NVIDIA GeForce GTX 980) under `python=3.8.0`.

# %%
from rankDrugRev import RankDrugRev
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Model training from the beginning
# Here is the section where you train a pipeline from the beginning (i.e., not using the pretrained pipeline)

# %%
# instantiating the model class 
revRank_model = RankDrugRev()

# %%
# loading default dataset (https://archive.ics.uci.edu/ml/datasets/Drug+Review+Dataset+%28Drugs.com%29)  
revRank_model.load_data() 
revRank_model.raw_data_train.head(10)
# Out:
#        id                            drugName                     condition  \
# 0  206461                           Valsartan  Left Ventricular Dysfunction
# 1   95260                          Guanfacine                          ADHD
# 2   92703                              Lybrel                 Birth Control
# 3  138000                          Ortho Evra                 Birth Control
# 4   35696            Buprenorphine / naloxone             Opiate Dependence
# 5  155963                              Cialis  Benign Prostatic Hyperplasia
# 6  165907                      Levonorgestrel       Emergency Contraception
# 7  102654                        Aripiprazole               Bipolar Disorde
# 8   74811                              Keppra                      Epilepsy
# 9   48928  Ethinyl estradiol / levonorgestrel                 Birth Control
#
#                                               review  rating       date  \
# ...

# %%
# fitting preprocessesing pipeline 
revRank_model.fit_preprocess()

# %%
# applying the pipeline
X_obs_train, y_obs_train, idx_known = revRank_model.transform_preprocess(data = 'train')  # idx_known is the index of the data in the dataframe for which preprocessing pipeline has information

# %%
# modeling the train set using GPU and cuDNN
model, history = revRank_model.lstm_model(X_obs_train, y_obs_train, pretrained = False)
# Out:
# Epoch 1/4
# 3323/3323 [==============================] - 1272s 380ms/step - loss: 0.6600 - val_loss: 0.5930
# Epoch 2/4
# 3323/3323 [==============================] - 1258s 379ms/step - loss: 0.5605 - val_loss: 0.5447
# Epoch 3/4
# 3323/3323 [==============================] - 1253s 377ms/step - loss: 0.5224 - val_loss: 0.5348
# Epoch 4/4
# 3323/3323 [==============================] - 1258s 379ms/step - loss: 0.4994 - val_loss: 0.5289

# %%
# applying the trained model on the training dataset
y_pred_train = model.predict(X_obs_train)

# %%
# plotting observed and predicted test 
revRank_model.plot_performance(y_obs_train, y_pred_train)

# %% [markdown]
# The plot above indicates that the model can find the dominant structure in the usefulness of the reviews. But we still need to deploy the entire pipline on test subset.

# %%
# deploying trained model on unseen test data set that is already loaded by executing .load_data()
X_test, y_obs_test, idx = revRank_model.transform_preprocess(data = 'test')

# %%
y_pred_test = model.predict(X_test)

# %%
# plotting observed and predicted test
revRank_model.plot_performance(y_obs_test, y_pred_test)

# %% [markdown]
# The performance on the test subset is very similar to the training subset.
# So we save this model:

# %%
# saving trained model
revRank_model.save_model("preprcc.dill", "lstm_model.h5", model = model)

# %% [markdown]
# ### Using the pre-trained model
#
# Wihtout going through the `RankDrugRev` class, there is also a standalone function in the `rankDrugRev` module that takes in a dataframe and ranks it using a *pre-trained* model (saved as `preprcc.dill` and `lstm_model.h5` in this repository).

# %%
from rankDrugRev import rank_reviews

# %%
# making an example dataframe for test
import numpy as np
df = revRank_model.raw_data_test.iloc[np.random.randint(1000,2000,20),:]

# %%
df.head(20)
# Out:
#           id                        drugName  \
# 1920  110922                         Farxiga
# 1992  152707                      Furosemide
# 1514   93573                     Oxymorphone
# 1226   50293                      Gabapentin
# 1116  174063                          Valium
# 1469   78309                      Tapentadol
# 1616  163105                            ella
# 1020   19032                Chlordiazepoxide
# 1535  136936                    Isotretinoin
# 1339   96160                      Sertraline
# 1146  117413                          Jublia
# 1892  178934                         Victoza
# 1572   19148                      Pregabalin
# 1349  136224                          Relpax
# 1501  144963                    Etonogestrel
# 1524  199581                    Depo-Provera
# 1366  131830                      Effexor XR
# 1241   43189                          Sronyx
# 1476   90115  Pneumococcal 13-valent vaccine
# 1672   19297                      Pregabalin
#
# ...

# %%
df_ranked = rank_reviews(df)

# %%
df_ranked.head(20)
# Out:
#           id                        drugName  \
# 1226   50293                      Gabapentin
# 1020   19032                Chlordiazepoxide
# 1366  131830                      Effexor XR
# 1116  174063                          Valium
# 1672   19297                      Pregabalin
# 1469   78309                      Tapentadol
# 1339   96160                      Sertraline
# 1892  178934                         Victoza
# 1349  136224                          Relpax
# 1514   93573                     Oxymorphone
# 1572   19148                      Pregabalin
# 1616  163105                            ella
# 1146  117413                          Jublia
# 1241   43189                          Sronyx
# 1524  199581                    Depo-Provera
# 1535  136936                    Isotretinoin
# 1501  144963                    Etonogestrel
# 1920  110922                         Farxiga
# 1992  152707                      Furosemide
# 1476   90115  Pneumococcal 13-valent vaccine
#
# ...

# %% [markdown]
# ## As you see, the ranked dataframe shows most of the knwon high `usefullCount` have been corretly located near the top of the table. Moreover, there are 3 rows that have (correctly) returned `NaN` for the new `usefullness` column since they have not been fitted for in the preprocessing pipilne.
